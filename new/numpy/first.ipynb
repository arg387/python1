# %%
import numpy as np
rent = [1500,1500,1500,1500,1750,1750]
""" numpy array example is shown below  """
rent = np.array([1500,1500,1500,1500,1750,1750])
print(rent)
# Out:
# [1500 1500 1500 1500 1750 1750]

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.9 MB 7.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.8/12.9 MB 5.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/12.9 MB 4.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 3.4/12.9 MB 4.5 MB/s eta 0:00:03
#    ------------- -------------------------- 4.2/12.9 MB 4.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.9 MB 4.2 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.9 MB 4.2 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.9 MB 4.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 7.6/12.9 MB 4.2 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.9 MB 4.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 9.2/12.9 MB 4.1 MB/s eta 0:00:01
# ...

# %%
notification = np.array([15,22,10,18,17,12])
""" If you already import numpy, you can use numpy array function in all boxes in a code file.""" 
print(notification)
# Out:
# [15 22 10 18 17 12]
