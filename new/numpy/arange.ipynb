# %% [markdown]
# .arange() examples

# %%
import numpy as np
arr_comet = np.arange(start=1986,stop=3000,step=75)
print(arr_comet)
# Out:
# [1986 2061 2136 2211 2286 2361 2436 2511 2586 2661 2736 2811 2886 2961]
