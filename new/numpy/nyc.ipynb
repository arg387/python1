# %% [markdown]
# # this is a practice file

# %%
import numpy as np
coffee = np.array([3, 2, 1, 0, 1])

print(coffee[0:2])    # Output: [3 2]
print(coffee[2:])     # Output: [1 0 1]
print(coffee[-2:])    # Output: [0 1]
# Out:
# [3 2]
# [1 0 1]
# [0 1]

# %%
Pops_nyc = np.array([
    19571216,
    19673200,
    19854526,
    20104710,
    19463131,
    19544098,
    19593849,
    19636391,
    19657321,
    19653431,
    19626488
])
print(Pops_nyc[0])
print(Pops_nyc[-2])
print(abs(Pops_nyc[0] - Pops_nyc[-1]))
print(Pops_nyc[1:4])
# Out:
# 19571216
# 19653431
# 55272
# [19673200 19854526 20104710]
